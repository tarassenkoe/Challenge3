# %%
import csv

# Specify the path to the CSV file
csv_file_path = 'budget_data.csv'

# Open the CSV file and create a reader object
with open(csv_file_path, 'r') as file:
    reader = csv.reader(file)

    # Iterate over each row in the CSV file
    for row in reader:
        # Access the individual values in each row
        for value in row:
            print(value)
# Out:
# Date
# Profit/Losses
# Jan-10
# 1088983
# Feb-10
# -354534
# Mar-10
# 276622
# Apr-10
# -728133
# May-10
# 852993
# Jun-10
# 563721
# Jul-10
# -535208
# Aug-10
# 632349
# Sep-10
# -173744
# Oct-10
# 950741
# Nov-10
# -785750
# Dec-10
# -1194133
# Jan-11
# -589576
# Feb-11
# -883921
# Mar-11
# 443564
# Apr-11
# 837887
# May-11
# 1081472
# Jun-11
# 464033
# Jul-11
# -1066544
# Aug-11
# 323846
# Sep-11
# -806551
# Oct-11
# 487053
# Nov-11
# 1128811
# Dec-11
# 791398
# Jan-12
# 739367
# Feb-12
# -197825
# Mar-12
# 666016
# Apr-12
# 589771
# May-12
# 489290
# Jun-12
# -471439
# Jul-12
# 120417
# Aug-12
# 175347
# Sep-12
# 855449
# Oct-12
# 605195
# Nov-12
# -235220
# Dec-12
# 347138
# Jan-13
# 298510
# Feb-13
# 163254
# Mar-13
# 1141840
# Apr-13
# 542630
# May-13
# 99841
# Jun-13
# 752765
# Jul-13
# -252949
# Aug-13
# 914424
# Sep-13
# 679524
# Oct-13
# 514377
# Nov-13
# 462102
# Dec-13
# 159782
# Jan-14
# 878810
# Feb-14
# -946748
# Mar-14
# 340335
# Apr-14
# 292032
# May-14
# 502266
# Jun-14
# 265852
# Jul-14
# 851017
# Aug-14
# -549615
# Sep-14
# 290162
# Oct-14
# 755391
# Nov-14
# 1073202
# Dec-14
# 313000
# Jan-15
# 241132
# Feb-15
# 1036589
# Mar-15
# 853904
# Apr-15
# -388932
# May-15
# 982952
# Jun-15
# 537759
# Jul-15
# 547784
# Aug-15
# -496214
# Sep-15
# 854181
# Oct-15
# 934719
# Nov-15
# -288531
# Dec-15
# -184383
# Jan-16
# 659541
# Feb-16
# -1149123
# Mar-16
# 355882
# Apr-16
# 662284
# May-16
# 518681
# Jun-16
# -748256
# Jul-16
# -910775
# Aug-16
# 951227
# Sep-16
# 898241
# Oct-16
# -729004
# Nov-16
# -112209
# Dec-16
# 516313
# Jan-17
# 607208
# Feb-17
# 382539

# %%
with open('budget_data.csv', 'r') as file:
  csv_reader = csv.reader(file)
# Fetch the first row which contains the column names
  column_names = next(csv_reader)
# Print the column names
for column_name in column_names:
  print(column_name)
# Out:
# Date
# Profit/Losses

# %%
import csv

def extract_data_from_csv(csv_file_path):
    with open(csv_file_path, 'r') as csv_file:
        csv_reader = csv.reader(csv_file)

        # Skip the header row if needed
        # next(csv_reader)

        for row in csv_reader:
            # Access data from each row using indexing
            # For example, row[0] will give you the value in the first column

            # Process and use the data as required
            print(row)

# %%
import csv

def extract_data_from_csv(filename):
    data = []
    with open(filename, 'r') as file:
        csv_reader = csv.reader(file)
        for row in csv_reader:
            data.append(row)
    return data

data = extract_data_from_csv("budget_data.csv")
unique_dates = set()

# Iterate over each entry in the column
if data is None:
    data = []

for entry in data:
    unique_dates.add(entry[0])

# Get the number of unique entries
num_unique_dates = len(unique_dates)

# Print the result
print(num_unique_dates)
# Out:
# 87

# %%
#There are 87 unique months included in the dataset.

# %%
data1=extract_data_from_csv("budget_data.csv")
data1
# Out:
# [['Date', 'Profit/Losses'],
#  ['Jan-10', '1088983'],
#  ['Feb-10', '-354534'],
#  ['Mar-10', '276622'],
#  ['Apr-10', '-728133'],
#  ['May-10', '852993'],
#  ['Jun-10', '563721'],
#  ['Jul-10', '-535208'],
#  ['Aug-10', '632349'],
#  ['Sep-10', '-173744'],
#  ['Oct-10', '950741'],
#  ['Nov-10', '-785750'],
#  ['Dec-10', '-1194133'],
#  ['Jan-11', '-589576'],
#  ['Feb-11', '-883921'],
#  ['Mar-11', '443564'],
#  ['Apr-11', '837887'],
#  ['May-11', '1081472'],
#  ['Jun-11', '464033'],
#  ['Jul-11', '-1066544'],
#  ['Aug-11', '323846'],
#  ['Sep-11', '-806551'],
#  ['Oct-11', '487053'],
#  ['Nov-11', '1128811'],
#  ['Dec-11', '791398'],
#  ['Jan-12', '739367'],
#  ['Feb-12', '-197825'],
#  ['Mar-12', '666016'],
#  ['Apr-12', '589771'],
#  ['May-12', '489290'],
#  ['Jun-12', '-471439'],
#  ['Jul-12', '120417'],
#  ['Aug-12', '175347'],
#  ['Sep-12', '855449'],
#  ['Oct-12', '605195'],
#  ['Nov-12', '-235220'],
#  ['Dec-12', '347138'],
#  ['Jan-13', '298510'],
#  ['Feb-13', '163254'],
#  ['Mar-13', '1141840'],
#  ['Apr-13', '542630'],
#  ['May-13', '99841'],
#  ['Jun-13', '752765'],
#  ['Jul-13', '-252949'],
#  ['Aug-13', '914424'],
#  ['Sep-13', '679524'],
#  ['Oct-13', '514377'],
#  ['Nov-13', '462102'],
#  ['Dec-13', '159782'],
#  ['Jan-14', '878810'],
#  ['Feb-14', '-946748'],
#  ['Mar-14', '340335'],
#  ['Apr-14', '292032'],
#  ['May-14', '502266'],
#  ['Jun-14', '265852'],
#  ['Jul-14', '851017'],
#  ['Aug-14', '-549615'],
#  ['Sep-14', '290162'],
#  ['Oct-14', '755391'],
#  ['Nov-14', '1073202'],
#  ['Dec-14', '313000'],
#  ['Jan-15', '241132'],
#  ['Feb-15', '1036589'],
#  ['Mar-15', '853904'],
#  ['Apr-15', '-388932'],
#  ['May-15', '982952'],
#  ['Jun-15', '537759'],
#  ['Jul-15', '547784'],
#  ['Aug-15', '-496214'],
#  ['Sep-15', '854181'],
#  ['Oct-15', '934719'],
#  ['Nov-15', '-288531'],
#  ['Dec-15', '-184383'],
#  ['Jan-16', '659541'],
#  ['Feb-16', '-1149123'],
#  ['Mar-16', '355882'],
#  ['Apr-16', '662284'],
#  ['May-16', '518681'],
#  ['Jun-16', '-748256'],
#  ['Jul-16', '-910775'],
#  ['Aug-16', '951227'],
#  ['Sep-16', '898241'],
#  ['Oct-16', '-729004'],
#  ['Nov-16', '-112209'],
#  ['Dec-16', '516313'],
#  ['Jan-17', '607208'],
#  ['Feb-17', '382539']]

# %%
second_entries = [entry[1] for entry in data1]
first_entries=[entry[0] for entry in data1]

# %%
second_entries
first_entries
# Out:
# ['Date',
#  'Jan-10',
#  'Feb-10',
#  'Mar-10',
#  'Apr-10',
#  'May-10',
#  'Jun-10',
#  'Jul-10',
#  'Aug-10',
#  'Sep-10',
#  'Oct-10',
#  'Nov-10',
#  'Dec-10',
#  'Jan-11',
#  'Feb-11',
#  'Mar-11',
#  'Apr-11',
#  'May-11',
#  'Jun-11',
#  'Jul-11',
#  'Aug-11',
#  'Sep-11',
#  'Oct-11',
#  'Nov-11',
#  'Dec-11',
#  'Jan-12',
#  'Feb-12',
#  'Mar-12',
#  'Apr-12',
#  'May-12',
#  'Jun-12',
#  'Jul-12',
#  'Aug-12',
#  'Sep-12',
#  'Oct-12',
#  'Nov-12',
#  'Dec-12',
#  'Jan-13',
#  'Feb-13',
#  'Mar-13',
#  'Apr-13',
#  'May-13',
#  'Jun-13',
#  'Jul-13',
#  'Aug-13',
#  'Sep-13',
#  'Oct-13',
#  'Nov-13',
#  'Dec-13',
#  'Jan-14',
#  'Feb-14',
#  'Mar-14',
#  'Apr-14',
#  'May-14',
#  'Jun-14',
#  'Jul-14',
#  'Aug-14',
#  'Sep-14',
#  'Oct-14',
#  'Nov-14',
#  'Dec-14',
#  'Jan-15',
#  'Feb-15',
#  'Mar-15',
#  'Apr-15',
#  'May-15',
#  'Jun-15',
#  'Jul-15',
#  'Aug-15',
#  'Sep-15',
#  'Oct-15',
#  'Nov-15',
#  'Dec-15',
#  'Jan-16',
#  'Feb-16',
#  'Mar-16',
#  'Apr-16',
#  'May-16',
#  'Jun-16',
#  'Jul-16',
#  'Aug-16',
#  'Sep-16',
#  'Oct-16',
#  'Nov-16',
#  'Dec-16',
#  'Jan-17',
#  'Feb-17']

# %%
#Sum of Profit/Losses:
sum_of_second_entries = sum(map(int, [x for x in second_entries if x.isdigit()]))

print(sum_of_second_entries)
# Out:
# 37343515

# %%
entries=[x for x in second_entries if x.isdigit()]

# %%
int_list = [int(num) for num in entries]

print("List of integers:", int_list)
# Out:
# List of integers: [1088983, 276622, 852993, 563721, 632349, 950741, 443564, 837887, 1081472, 464033, 323846, 487053, 1128811, 791398, 739367, 666016, 589771, 489290, 120417, 175347, 855449, 605195, 347138, 298510, 163254, 1141840, 542630, 99841, 752765, 914424, 679524, 514377, 462102, 159782, 878810, 340335, 292032, 502266, 265852, 851017, 290162, 755391, 1073202, 313000, 241132, 1036589, 853904, 982952, 537759, 547784, 854181, 934719, 659541, 355882, 662284, 518681, 951227, 898241, 516313, 607208, 382539]

# %%
#Sum of Profit/Losses:
sum(int_list)
# Out:
# 37343515

# %%
changes = []
for i in range(1, len(int_list)):
    change = int_list[i] - int_list[i - 1]
    changes.append(change)

# Calculate the average of the changes
average_change = sum(changes) / len(changes) if len(changes) > 0 else 0

# Print the changes and average change
print("Changes in Profit/Losses over the entire period:", changes)
print("Average of those changes:", average_change)
# Out:
# Changes in Profit/Losses over the entire period: [-812361, 576371, -289272, 68628, 318392, -507177, 394323, 243585, -617439, -140187, 163207, 641758, -337413, -52031, -73351, -76245, -100481, -368873, 54930, 680102, -250254, -258057, -48628, -135256, 978586, -599210, -442789, 652924, 161659, -234900, -165147, -52275, -302320, 719028, -538475, -48303, 210234, -236414, 585165, -560855, 465229, 317811, -760202, -71868, 795457, -182685, 129048, -445193, 10025, 306397, 80538, -275178, -303659, 306402, -143603, 432546, -52986, -381928, 90895, -224669]
# Average of those changes: -11774.066666666668

# %%
#Profit/Losses:
int_list
#dates:
first_entries
max_change = 0
max_change_date = None

# Find the maximum change in Profit/Losses and the associated date
for i in range(1, len(int_list)):
    change = int_list[i] - int_list[i - 1]
    if change > max_change:
        max_change = change
        max_change_date = first_entries[i]

# Print the maximum change and its associated date
print("Maximum change in Profit/Losses:", max_change)
print("Associated date:", max_change_date)
# Out:
# Maximum change in Profit/Losses: 978586
# Associated date: Jan-12

# %%
greatest_decrease = 0
decrease_date = None

# Find the greatest decrease in Profit/Losses and the associated date
for i in range(1, len(int_list)):
    change = int_list[i] - int_list[i - 1]
    if change < greatest_decrease:
        greatest_decrease = change
        decrease_date = first_entries[i]

# Print the greatest decrease and its associated date
print("Greatest decrease in Profit/Losses:", greatest_decrease)
print("Associated date:", decrease_date)
# Out:
# Greatest decrease in Profit/Losses: -812361
# Associated date: Jan-10

# %%
analysis = f"Analysis of Profit/Losses:\n"\
    f"Maximum change in Profit/Losses: {max_change} on {max_change_date}\n"\
    f"Greatest decrease in Profit/Losses: {greatest_decrease} on {decrease_date}\n"

# Print analysis to the terminal
print(analysis)

# Export analysis to a text file
file_name = "profit_loss_analysis_for_budget_data.txt"
with open(file_name, "w") as file:
    file.write(analysis)

print(f"Analysis exported to {file_name}")
# Out:
# Analysis of Profit/Losses:
# Maximum change in Profit/Losses: 978586 on Jan-12
# Greatest decrease in Profit/Losses: -812361 on Jan-10
#
# Analysis exported to profit_loss_analysis_for_budget_data.txt

# %%
#####Election Data Analysis######

# %%
import csv
filename="election_data.csv"
def extract_data_from_csv(filename):
    data = []
    with open(filename, 'r') as file:
        csv_reader = csv.reader(file)
        for row in csv_reader:
            data.append(row)
    return data

data = extract_data_from_csv("election_data.csv")

# %%
data
# Out:
# [['Ballot ID', 'County', 'Candidate'],
#  ['1323913', 'Jefferson', 'Charles Casper Stockham'],
#  ['1005842', 'Jefferson', 'Charles Casper Stockham'],
#  ['1880345', 'Jefferson', 'Charles Casper Stockham'],
#  ['1600337', 'Jefferson', 'Charles Casper Stockham'],
#  ['1835994', 'Jefferson', 'Charles Casper Stockham'],
#  ['1772756', 'Jefferson', 'Charles Casper Stockham'],
#  ['1920023', 'Jefferson', 'Charles Casper Stockham'],
#  ['1040408', 'Jefferson', 'Charles Casper Stockham'],
#  ['1018414', 'Jefferson', 'Charles Casper Stockham'],
#  ['1361118', 'Jefferson', 'Charles Casper Stockham'],
#  ['1045722', 'Jefferson', 'Charles Casper Stockham'],
#  ['1006975', 'Jefferson', 'Charles Casper Stockham'],
#  ['1489642', 'Jefferson', 'Charles Casper Stockham'],
#  ['1456389', 'Jefferson', 'Charles Casper Stockham'],
#  ['1936969', 'Jefferson', 'Charles Casper Stockham'],
#  ['1356658', 'Jefferson', 'Charles Casper Stockham'],
#  ['1651667', 'Jefferson', 'Charles Casper Stockham'],
#  ['1833621', 'Jefferson', 'Charles Casper Stockham'],
#  ['1730001', 'Jefferson', 'Charles Casper Stockham'],
#  ['1059252', 'Jefferson', 'Charles Casper Stockham'],
#  ['1279893', 'Jefferson', 'Charles Casper Stockham'],
#  ['1100426', 'Jefferson', 'Charles Casper Stockham'],
#  ['1855823', 'Jefferson', 'Charles Casper Stockham'],
#  ['1951080', 'Jefferson', 'Charles Casper Stockham'],
#  ['1345091', 'Jefferson', 'Charles Casper Stockham'],
#  ['1113764', 'Jefferson', 'Charles Casper Stockham'],
#  ['1366270', 'Jefferson', 'Charles Casper Stockham'],
#  ['1431431', 'Jefferson', 'Charles Casper Stockham'],
#  ['1402951', 'Jefferson', 'Charles Casper Stockham'],
#  ['1708981', 'Jefferson', 'Charles Casper Stockham'],
#  ['1245209', 'Jefferson', 'Charles Casper Stockham'],
#  ['1046171', 'Jefferson', 'Charles Casper Stockham'],
#  ['1418131', 'Jefferson', 'Charles Casper Stockham'],
#  ['1713581', 'Jefferson', 'Charles Casper Stockham'],
#  ['1353343', 'Jefferson', 'Charles Casper Stockham'],
#  ['1176460', 'Jefferson', 'Charles Casper Stockham'],
#  ['1297739', 'Jefferson', 'Charles Casper Stockham'],
#  ['1991199', 'Jefferson', 'Charles Casper Stockham'],
#  ['1532445', 'Jefferson', 'Charles Casper Stockham'],
#  ['1884329', 'Jefferson', 'Charles Casper Stockham'],
#  ['1104694', 'Jefferson', 'Charles Casper Stockham'],
#  ['1754412', 'Jefferson', 'Charles Casper Stockham'],
#  ['1172260', 'Jefferson', 'Charles Casper Stockham'],
#  ['1236187', 'Jefferson', 'Charles Casper Stockham'],
#  ['1630539', 'Jefferson', 'Charles Casper Stockham'],
#  ['1089226', 'Jefferson', 'Charles Casper Stockham'],
#  ['1128099', 'Jefferson', 'Charles Casper Stockham'],
#  ['1767213', 'Jefferson', 'Charles Casper Stockham'],
#  ['1429526', 'Jefferson', 'Charles Casper Stockham'],
#  ['1870348', 'Jefferson', 'Charles Casper Stockham'],
#  ['1286907', 'Jefferson', 'Charles Casper Stockham'],
#  ['1020447', 'Jefferson', 'Charles Casper Stockham'],
#  ['1918463', 'Jefferson', 'Charles Casper Stockham'],
#  ['1038864', 'Jefferson', 'Charles Casper Stockham'],
#  ['1222247', 'Jefferson', 'Charles Casper Stockham'],
#  ['1720375', 'Jefferson', 'Charles Casper Stockham'],
#  ['1436548', 'Jefferson', 'Charles Casper Stockham'],
#  ['1665518', 'Jefferson', 'Charles Casper Stockham'],
#  ['1591563', 'Jefferson', 'Charles Casper Stockham'],
#  ['1309674', 'Jefferson', 'Charles Casper Stockham'],
#  ['1148557', 'Jefferson', 'Charles Casper Stockham'],
#  ['1255268', 'Jefferson', 'Charles Casper Stockham'],
#  ['1372790', 'Jefferson', 'Charles Casper Stockham'],
#  ['1240771', 'Jefferson', 'Charles Casper Stockham'],
#  ['1489979', 'Jefferson', 'Charles Casper Stockham'],
#  ['1018662', 'Jefferson', 'Charles Casper Stockham'],
#  ['1070029', 'Jefferson', 'Charles Casper Stockham'],
#  ['1499371', 'Jefferson', 'Charles Casper Stockham'],
#  ['1140828', 'Jefferson', 'Charles Casper Stockham'],
#  ['1717909', 'Jefferson', 'Charles Casper Stockham'],
#  ['1715840', 'Jefferson', 'Charles Casper Stockham'],
#  ['1770375', 'Jefferson', 'Charles Casper Stockham'],
#  ['1836676', 'Jefferson', 'Charles Casper Stockham'],
#  ['1135426', 'Jefferson', 'Charles Casper Stockham'],
#  ['1257861', 'Jefferson', 'Charles Casper Stockham'],
#  ['1747758', 'Jefferson', 'Charles Casper Stockham'],
#  ['1555167', 'Jefferson', 'Charles Casper Stockham'],
#  ['1664996', 'Jefferson', 'Charles Casper Stockham'],
#  ['1221843', 'Jefferson', 'Charles Casper Stockham'],
#  ['1030534', 'Jefferson', 'Charles Casper Stockham'],
#  ['1968603', 'Jefferson', 'Charles Casper Stockham'],
#  ['1969306', 'Jefferson', 'Charles Casper Stockham'],
#  ['1203383', 'Jefferson', 'Charles Casper Stockham'],
#  ['1083951', 'Jefferson', 'Charles Casper Stockham'],
#  ['1624829', 'Jefferson', 'Charles Casper Stockham'],
#  ['1149509', 'Jefferson', 'Charles Casper Stockham'],
#  ['1595813', 'Jefferson', 'Charles Casper Stockham'],
#  ['1977881', 'Jefferson', 'Charles Casper Stockham'],
#  ['1424599', 'Jefferson', 'Charles Casper Stockham'],
#  ['1198278', 'Jefferson', 'Charles Casper Stockham'],
#  ['1881727', 'Jefferson', 'Charles Casper Stockham'],
#  ['1350616', 'Jefferson', 'Charles Casper Stockham'],
#  ['1841460', 'Jefferson', 'Charles Casper Stockham'],
#  ['1355784', 'Jefferson', 'Charles Casper Stockham'],
#  ['1769848', 'Jefferson', 'Charles Casper Stockham'],
#  ['1818383', 'Jefferson', 'Charles Casper Stockham'],
#  ['1187011', 'Jefferson', 'Charles Casper Stockham'],
#  ['1151108', 'Jefferson', 'Charles Casper Stockham'],
#  ['1624110', 'Jefferson', 'Charles Casper Stockham'],
#  ['1721513', 'Jefferson', 'Charles Casper Stockham'],
#  ['1908437', 'Jefferson', 'Charles Casper Stockham'],
#  ['1516123', 'Jefferson', 'Charles Casper Stockham'],
#  ['1936748', 'Jefferson', 'Charles Casper Stockham'],
#  ['1454824', 'Jefferson', 'Charles Casper Stockham'],
#  ['1500106', 'Jefferson', 'Charles Casper Stockham'],
#  ['1792491', 'Jefferson', 'Charles Casper Stockham'],
#  ['1024294', 'Jefferson', 'Charles Casper Stockham'],
#  ['1137500', 'Jefferson', 'Charles Casper Stockham'],
#  ['1534632', 'Jefferson', 'Charles Casper Stockham'],
#  ['1307407', 'Jefferson', 'Charles Casper Stockham'],
#  ['1461448', 'Jefferson', 'Charles Casper Stockham'],
#  ['1990526', 'Jefferson', 'Charles Casper Stockham'],
#  ['1421973', 'Jefferson', 'Charles Casper Stockham'],
#  ['1510334', 'Jefferson', 'Charles Casper Stockham'],
#  ['1454191', 'Jefferson', 'Charles Casper Stockham'],
#  ['1080087', 'Jefferson', 'Charles Casper Stockham'],
#  ['1984701', 'Jefferson', 'Charles Casper Stockham'],
#  ['1201774', 'Jefferson', 'Charles Casper Stockham'],
#  ['1798781', 'Jefferson', 'Charles Casper Stockham'],
#  ['1212340', 'Jefferson', 'Charles Casper Stockham'],
#  ['1340666', 'Jefferson', 'Charles Casper Stockham'],
#  ['1639571', 'Jefferson', 'Charles Casper Stockham'],
#  ['1276307', 'Jefferson', 'Charles Casper Stockham'],
#  ['1557865', 'Jefferson', 'Charles Casper Stockham'],
#  ['1740719', 'Jefferson', 'Charles Casper Stockham'],
#  ['1655485', 'Jefferson', 'Charles Casper Stockham'],
#  ['1916217', 'Jefferson', 'Charles Casper Stockham'],
#  ['1527052', 'Jefferson', 'Charles Casper Stockham'],
#  ['1012547', 'Jefferson', 'Charles Casper Stockham'],
#  ['1482189', 'Jefferson', 'Charles Casper Stockham'],
#  ['1550491', 'Jefferson', 'Charles Casper Stockham'],
#  ['1129835', 'Jefferson', 'Charles Casper Stockham'],
#  ['1696986', 'Jefferson', 'Charles Casper Stockham'],
#  ['1652386', 'Jefferson', 'Charles Casper Stockham'],
#  ['1999745', 'Jefferson', 'Charles Casper Stockham'],
#  ['1148362', 'Jefferson', 'Charles Casper Stockham'],
#  ['1670122', 'Jefferson', 'Charles Casper Stockham'],
#  ['1569410', 'Jefferson', 'Charles Casper Stockham'],
#  ['1716895', 'Jefferson', 'Charles Casper Stockham'],
#  ['1848448', 'Jefferson', 'Charles Casper Stockham'],
#  ['1554737', 'Jefferson', 'Charles Casper Stockham'],
#  ['1304024', 'Jefferson', 'Charles Casper Stockham'],
#  ['1582937', 'Jefferson', 'Charles Casper Stockham'],
#  ['1196678', 'Jefferson', 'Charles Casper Stockham'],
#  ['1996019', 'Jefferson', 'Charles Casper Stockham'],
#  ['1611981', 'Jefferson', 'Charles Casper Stockham'],
#  ['1446453', 'Jefferson', 'Charles Casper Stockham'],
#  ['1006613', 'Jefferson', 'Charles Casper Stockham'],
#  ['1097389', 'Jefferson', 'Charles Casper Stockham'],
#  ['1664361', 'Jefferson', 'Charles Casper Stockham'],
#  ['1227288', 'Jefferson', 'Charles Casper Stockham'],
#  ['1418307', 'Jefferson', 'Charles Casper Stockham'],
#  ['1074104', 'Jefferson', 'Charles Casper Stockham'],
#  ['1400119', 'Jefferson', 'Charles Casper Stockham'],
#  ['1825564', 'Jefferson', 'Charles Casper Stockham'],
#  ['1994963', 'Jefferson', 'Charles Casper Stockham'],
#  ['1561521', 'Jefferson', 'Charles Casper Stockham'],
#  ['1938184', 'Jefferson', 'Charles Casper Stockham'],
#  ['1057307', 'Jefferson', 'Charles Casper Stockham'],
#  ['1770098', 'Jefferson', 'Charles Casper Stockham'],
#  ['1282407', 'Jefferson', 'Charles Casper Stockham'],
#  ['1381089', 'Jefferson', 'Charles Casper Stockham'],
#  ['1691848', 'Jefferson', 'Charles Casper Stockham'],
#  ['1378511', 'Jefferson', 'Charles Casper Stockham'],
#  ['1302170', 'Jefferson', 'Charles Casper Stockham'],
#  ['1791456', 'Jefferson', 'Charles Casper Stockham'],
#  ['1406731', 'Jefferson', 'Charles Casper Stockham'],
#  ['1436508', 'Jefferson', 'Charles Casper Stockham'],
#  ['1900461', 'Jefferson', 'Charles Casper Stockham'],
#  ['1823528', 'Jefferson', 'Charles Casper Stockham'],
#  ['1529682', 'Jefferson', 'Charles Casper Stockham'],
#  ['1912903', 'Jefferson', 'Charles Casper Stockham'],
#  ['1029656', 'Jefferson', 'Charles Casper Stockham'],
#  ['1613151', 'Jefferson', 'Charles Casper Stockham'],
#  ['1928136', 'Jefferson', 'Charles Casper Stockham'],
#  ['1366457', 'Jefferson', 'Charles Casper Stockham'],
#  ['1623242', 'Jefferson', 'Charles Casper Stockham'],
#  ['1830853', 'Jefferson', 'Charles Casper Stockham'],
#  ['1494343', 'Jefferson', 'Charles Casper Stockham'],
#  ['1880341', 'Jefferson', 'Charles Casper Stockham'],
#  ['1524755', 'Jefferson', 'Charles Casper Stockham'],
#  ['1010806', 'Jefferson', 'Charles Casper Stockham'],
#  ['1368735', 'Jefferson', 'Charles Casper Stockham'],
#  ['1984217', 'Jefferson', 'Charles Casper Stockham'],
#  ['1587228', 'Jefferson', 'Charles Casper Stockham'],
#  ['1445587', 'Jefferson', 'Charles Casper Stockham'],
#  ['1050479', 'Jefferson', 'Charles Casper Stockham'],
#  ['1129390', 'Jefferson', 'Charles Casper Stockham'],
#  ['1378906', 'Jefferson', 'Charles Casper Stockham'],
#  ['1378668', 'Jefferson', 'Charles Casper Stockham'],
#  ['1086824', 'Jefferson', 'Charles Casper Stockham'],
#  ['1597420', 'Jefferson', 'Charles Casper Stockham'],
#  ['1855571', 'Jefferson', 'Charles Casper Stockham'],
#  ['1521117', 'Jefferson', 'Charles Casper Stockham'],
#  ['1721050', 'Jefferson', 'Charles Casper Stockham'],
#  ['1719319', 'Jefferson', 'Charles Casper Stockham'],
#  ['1223724', 'Jefferson', 'Charles Casper Stockham'],
#  ['1187290', 'Jefferson', 'Charles Casper Stockham'],
#  ['1998546', 'Jefferson', 'Charles Casper Stockham'],
#  ['1322198', 'Jefferson', 'Charles Casper Stockham'],
#  ['1555463', 'Jefferson', 'Charles Casper Stockham'],
#  ['1343246', 'Jefferson', 'Charles Casper Stockham'],
#  ['1567089', 'Jefferson', 'Charles Casper Stockham'],
#  ['1985311', 'Jefferson', 'Charles Casper Stockham'],
#  ['1167893', 'Jefferson', 'Charles Casper Stockham'],
#  ['1686706', 'Jefferson', 'Charles Casper Stockham'],
#  ['1095686', 'Jefferson', 'Charles Casper Stockham'],
#  ['1898947', 'Jefferson', 'Charles Casper Stockham'],
#  ['1891344', 'Jefferson', 'Charles Casper Stockham'],
#  ['1581189', 'Jefferson', 'Charles Casper Stockham'],
#  ['1335615', 'Jefferson', 'Charles Casper Stockham'],
#  ['1069823', 'Jefferson', 'Charles Casper Stockham'],
#  ['1495599', 'Jefferson', 'Charles Casper Stockham'],
#  ['1083555', 'Jefferson', 'Charles Casper Stockham'],
#  ['1320135', 'Jefferson', 'Charles Casper Stockham'],
#  ['1423228', 'Jefferson', 'Charles Casper Stockham'],
#  ['1300494', 'Jefferson', 'Charles Casper Stockham'],
#  ['1578447', 'Jefferson', 'Charles Casper Stockham'],
#  ['1020278', 'Jefferson', 'Charles Casper Stockham'],
#  ['1350623', 'Jefferson', 'Charles Casper Stockham'],
#  ['1769692', 'Jefferson', 'Charles Casper Stockham'],
#  ['1618962', 'Jefferson', 'Charles Casper Stockham'],
#  ['1952188', 'Jefferson', 'Charles Casper Stockham'],
#  ['1726150', 'Jefferson', 'Charles Casper Stockham'],
#  ['1337873', 'Jefferson', 'Charles Casper Stockham'],
#  ['1143194', 'Jefferson', 'Charles Casper Stockham'],
#  ['1625382', 'Jefferson', 'Charles Casper Stockham'],
#  ['1258188', 'Jefferson', 'Charles Casper Stockham'],
#  ['1127769', 'Jefferson', 'Charles Casper Stockham'],
#  ['1111925', 'Jefferson', 'Charles Casper Stockham'],
#  ['1695303', 'Jefferson', 'Charles Casper Stockham'],
#  ['1746732', 'Jefferson', 'Charles Casper Stockham'],
#  ['1202604', 'Jefferson', 'Charles Casper Stockham'],
#  ['1769330', 'Jefferson', 'Charles Casper Stockham'],
#  ['1047751', 'Jefferson', 'Charles Casper Stockham'],
#  ['1745646', 'Jefferson', 'Charles Casper Stockham'],
#  ['1931345', 'Jefferson', 'Charles Casper Stockham'],
#  ['1590533', 'Jefferson', 'Charles Casper Stockham'],
#  ['1588402', 'Jefferson', 'Charles Casper Stockham'],
#  ['1462729', 'Jefferson', 'Charles Casper Stockham'],
#  ['1071293', 'Jefferson', 'Charles Casper Stockham'],
#  ['1679251', 'Jefferson', 'Charles Casper Stockham'],
#  ['1726923', 'Jefferson', 'Charles Casper Stockham'],
#  ['1540685', 'Jefferson', 'Charles Casper Stockham'],
#  ['1816986', 'Jefferson', 'Charles Casper Stockham'],
#  ['1726661', 'Jefferson', 'Charles Casper Stockham'],
#  ['1274207', 'Jefferson', 'Charles Casper Stockham'],
#  ['1120764', 'Jefferson', 'Charles Casper Stockham'],
#  ['1967791', 'Jefferson', 'Charles Casper Stockham'],
#  ['1641441', 'Jefferson', 'Charles Casper Stockham'],
#  ['1043143', 'Jefferson', 'Charles Casper Stockham'],
#  ['1869988', 'Jefferson', 'Charles Casper Stockham'],
#  ['1408135', 'Jefferson', 'Charles Casper Stockham'],
#  ['1951536', 'Jefferson', 'Charles Casper Stockham'],
#  ['1969984', 'Jefferson', 'Charles Casper Stockham'],
#  ['1449018', 'Jefferson', 'Charles Casper Stockham'],
#  ['1953407', 'Jefferson', 'Charles Casper Stockham'],
#  ['1123998', 'Jefferson', 'Charles Casper Stockham'],
#  ['1890504', 'Jefferson', 'Charles Casper Stockham'],
#  ['1838570', 'Jefferson', 'Charles Casper Stockham'],
#  ['1480729', 'Jefferson', 'Charles Casper Stockham'],
#  ['1322842', 'Jefferson', 'Charles Casper Stockham'],
#  ['1636364', 'Jefferson', 'Charles Casper Stockham'],
#  ['1261020', 'Jefferson', 'Charles Casper Stockham'],
#  ['1237760', 'Jefferson', 'Charles Casper Stockham'],
#  ['1837626', 'Jefferson', 'Charles Casper Stockham'],
#  ['1313908', 'Jefferson', 'Charles Casper Stockham'],
#  ['1334155', 'Jefferson', 'Charles Casper Stockham'],
#  ['1609347', 'Jefferson', 'Charles Casper Stockham'],
#  ['1294281', 'Jefferson', 'Charles Casper Stockham'],
#  ['1609768', 'Jefferson', 'Charles Casper Stockham'],
#  ['1253113', 'Jefferson', 'Charles Casper Stockham'],
#  ['1819336', 'Jefferson', 'Charles Casper Stockham'],
#  ['1192847', 'Jefferson', 'Charles Casper Stockham'],
#  ['1255727', 'Jefferson', 'Charles Casper Stockham'],
#  ['1923877', 'Jefferson', 'Charles Casper Stockham'],
#  ['1949972', 'Jefferson', 'Charles Casper Stockham'],
#  ['1120329', 'Jefferson', 'Charles Casper Stockham'],
#  ['1531349', 'Jefferson', 'Charles Casper Stockham'],
#  ['1899138', 'Jefferson', 'Charles Casper Stockham'],
#  ['1229578', 'Jefferson', 'Charles Casper Stockham'],
#  ['1301985', 'Jefferson', 'Charles Casper Stockham'],
#  ['1130695', 'Jefferson', 'Charles Casper Stockham'],
#  ['1483525', 'Jefferson', 'Charles Casper Stockham'],
#  ['1160404', 'Jefferson', 'Charles Casper Stockham'],
#  ['1270313', 'Jefferson', 'Charles Casper Stockham'],
#  ['1591705', 'Jefferson', 'Charles Casper Stockham'],
#  ['1295339', 'Jefferson', 'Charles Casper Stockham'],
#  ['1403591', 'Jefferson', 'Charles Casper Stockham'],
#  ['1423472', 'Jefferson', 'Charles Casper Stockham'],
#  ['1314169', 'Jefferson', 'Charles Casper Stockham'],
#  ['1473022', 'Jefferson', 'Charles Casper Stockham'],
#  ['1093421', 'Jefferson', 'Charles Casper Stockham'],
#  ['1576171', 'Jefferson', 'Charles Casper Stockham'],
#  ['1861573', 'Jefferson', 'Charles Casper Stockham'],
#  ['1579725', 'Jefferson', 'Charles Casper Stockham'],
#  ['1315704', 'Jefferson', 'Charles Casper Stockham'],
#  ['1392207', 'Jefferson', 'Charles Casper Stockham'],
#  ['1105280', 'Jefferson', 'Charles Casper Stockham'],
#  ['1584067', 'Jefferson', 'Charles Casper Stockham'],
#  ['1967883', 'Jefferson', 'Charles Casper Stockham'],
#  ['1832136', 'Jefferson', 'Charles Casper Stockham'],
#  ['1343016', 'Jefferson', 'Charles Casper Stockham'],
#  ['1979718', 'Jefferson', 'Charles Casper Stockham'],
#  ['1288914', 'Jefferson', 'Charles Casper Stockham'],
#  ['1943335', 'Jefferson', 'Charles Casper Stockham'],
#  ['1846956', 'Jefferson', 'Charles Casper Stockham'],
#  ['1276994', 'Jefferson', 'Charles Casper Stockham'],
#  ['1702145', 'Jefferson', 'Charles Casper Stockham'],
#  ['1986949', 'Jefferson', 'Charles Casper Stockham'],
#  ['1547022', 'Jefferson', 'Charles Casper Stockham'],
#  ['1011479', 'Jefferson', 'Charles Casper Stockham'],
#  ['1881779', 'Jefferson', 'Charles Casper Stockham'],
#  ['1421106', 'Jefferson', 'Charles Casper Stockham'],
#  ['1061622', 'Jefferson', 'Charles Casper Stockham'],
#  ['1444797', 'Jefferson', 'Charles Casper Stockham'],
#  ['1565302', 'Jefferson', 'Charles Casper Stockham'],
#  ['1838275', 'Jefferson', 'Charles Casper Stockham'],
#  ['1909272', 'Jefferson', 'Charles Casper Stockham'],
#  ['1095852', 'Jefferson', 'Charles Casper Stockham'],
#  ['1472915', 'Jefferson', 'Charles Casper Stockham'],
#  ['1532720', 'Jefferson', 'Charles Casper Stockham'],
#  ['1901240', 'Jefferson', 'Charles Casper Stockham'],
#  ['1670403', 'Jefferson', 'Charles Casper Stockham'],
#  ['1253290', 'Jefferson', 'Charles Casper Stockham'],
#  ['1275329', 'Jefferson', 'Charles Casper Stockham'],
#  ['1495001', 'Jefferson', 'Charles Casper Stockham'],
#  ['1832211', 'Jefferson', 'Charles Casper Stockham'],
#  ['1013096', 'Jefferson', 'Charles Casper Stockham'],
#  ['1487980', 'Jefferson', 'Charles Casper Stockham'],
#  ['1046787', 'Jefferson', 'Charles Casper Stockham'],
#  ['1338271', 'Jefferson', 'Charles Casper Stockham'],
#  ['1942005', 'Jefferson', 'Charles Casper Stockham'],
#  ['1995687', 'Jefferson', 'Charles Casper Stockham'],
#  ['1127537', 'Jefferson', 'Charles Casper Stockham'],
#  ['1184119', 'Jefferson', 'Charles Casper Stockham'],
#  ['1303021', 'Jefferson', 'Charles Casper Stockham'],
#  ['1109394', 'Jefferson', 'Charles Casper Stockham'],
#  ['1241388', 'Jefferson', 'Charles Casper Stockham'],
#  ['1861568', 'Jefferson', 'Charles Casper Stockham'],
#  ['1467404', 'Jefferson', 'Charles Casper Stockham'],
#  ['1380660', 'Jefferson', 'Charles Casper Stockham'],
#  ['1649356', 'Jefferson', 'Charles Casper Stockham'],
#  ['1018488', 'Jefferson', 'Charles Casper Stockham'],
#  ['1985923', 'Jefferson', 'Charles Casper Stockham'],
#  ['1825376', 'Jefferson', 'Charles Casper Stockham'],
#  ['1430629', 'Jefferson', 'Charles Casper Stockham'],
#  ['1296922', 'Jefferson', 'Charles Casper Stockham'],
#  ['1851314', 'Jefferson', 'Charles Casper Stockham'],
#  ['1523064', 'Jefferson', 'Charles Casper Stockham'],
#  ['1808915', 'Jefferson', 'Charles Casper Stockham'],
#  ['1942400', 'Jefferson', 'Charles Casper Stockham'],
#  ['1305047', 'Jefferson', 'Charles Casper Stockham'],
#  ['1134128', 'Jefferson', 'Charles Casper Stockham'],
#  ['1239726', 'Jefferson', 'Charles Casper Stockham'],
#  ['1126623', 'Jefferson', 'Charles Casper Stockham'],
#  ['1627141', 'Jefferson', 'Charles Casper Stockham'],
#  ['1932140', 'Jefferson', 'Charles Casper Stockham'],
#  ['1029404', 'Jefferson', 'Charles Casper Stockham'],
#  ['1118975', 'Jefferson', 'Charles Casper Stockham'],
#  ['1535326', 'Jefferson', 'Charles Casper Stockham'],
#  ['1264895', 'Jefferson', 'Charles Casper Stockham'],
#  ['1466438', 'Jefferson', 'Charles Casper Stockham'],
#  ['1190683', 'Jefferson', 'Charles Casper Stockham'],
#  ['1994234', 'Jefferson', 'Charles Casper Stockham'],
#  ['1711794', 'Jefferson', 'Charles Casper Stockham'],
#  ['1953197', 'Jefferson', 'Charles Casper Stockham'],
#  ['1495389', 'Jefferson', 'Charles Casper Stockham'],
#  ['1639027', 'Jefferson', 'Charles Casper Stockham'],
#  ['1571378', 'Jefferson', 'Charles Casper Stockham'],
#  ['1962147', 'Jefferson', 'Charles Casper Stockham'],
#  ['1270768', 'Jefferson', 'Charles Casper Stockham'],
#  ['1789660', 'Jefferson', 'Charles Casper Stockham'],
#  ['1130975', 'Jefferson', 'Charles Casper Stockham'],
#  ['1961200', 'Jefferson', 'Charles Casper Stockham'],
#  ['1428185', 'Jefferson', 'Charles Casper Stockham'],
#  ['1899333', 'Jefferson', 'Charles Casper Stockham'],
#  ['1237978', 'Jefferson', 'Charles Casper Stockham'],
#  ['1182783', 'Jefferson', 'Charles Casper Stockham'],
#  ['1645063', 'Jefferson', 'Charles Casper Stockham'],
#  ['1001380', 'Jefferson', 'Charles Casper Stockham'],
#  ['1414234', 'Jefferson', 'Charles Casper Stockham'],
#  ['1299339', 'Jefferson', 'Charles Casper Stockham'],
#  ['1290896', 'Jefferson', 'Charles Casper Stockham'],
#  ['1651671', 'Jefferson', 'Charles Casper Stockham'],
#  ['1113522', 'Jefferson', 'Charles Casper Stockham'],
#  ['1662462', 'Jefferson', 'Charles Casper Stockham'],
#  ['1417151', 'Jefferson', 'Charles Casper Stockham'],
#  ['1536520', 'Jefferson', 'Charles Casper Stockham'],
#  ['1574292', 'Jefferson', 'Charles Casper Stockham'],
#  ['1858699', 'Jefferson', 'Charles Casper Stockham'],
#  ['1107568', 'Jefferson', 'Charles Casper Stockham'],
#  ['1429683', 'Jefferson', 'Charles Casper Stockham'],
#  ['1870197', 'Jefferson', 'Charles Casper Stockham'],
#  ['1308017', 'Jefferson', 'Charles Casper Stockham'],
#  ['1789211', 'Jefferson', 'Charles Casper Stockham'],
#  ['1016849', 'Jefferson', 'Charles Casper Stockham'],
#  ['1066673', 'Jefferson', 'Charles Casper Stockham'],
#  ['1477595', 'Jefferson', 'Charles Casper Stockham'],
#  ['1419253', 'Jefferson', 'Charles Casper Stockham'],
#  ['1444112', 'Jefferson', 'Charles Casper Stockham'],
#  ['1548175', 'Jefferson', 'Charles Casper Stockham'],
#  ['1389268', 'Jefferson', 'Charles Casper Stockham'],
#  ['1735243', 'Jefferson', 'Charles Casper Stockham'],
#  ['1667601', 'Jefferson', 'Charles Casper Stockham'],
#  ['1699118', 'Jefferson', 'Charles Casper Stockham'],
#  ['1570509', 'Jefferson', 'Charles Casper Stockham'],
#  ['1018997', 'Jefferson', 'Charles Casper Stockham'],
#  ['1365887', 'Jefferson', 'Charles Casper Stockham'],
#  ['1635558', 'Jefferson', 'Charles Casper Stockham'],
#  ['1310129', 'Jefferson', 'Charles Casper Stockham'],
#  ['1024682', 'Jefferson', 'Charles Casper Stockham'],
#  ['1498299', 'Jefferson', 'Charles Casper Stockham'],
#  ['1204015', 'Jefferson', 'Charles Casper Stockham'],
#  ['1206465', 'Jefferson', 'Charles Casper Stockham'],
#  ['1908118', 'Jefferson', 'Charles Casper Stockham'],
#  ['1077890', 'Jefferson', 'Charles Casper Stockham'],
#  ['1489342', 'Jefferson', 'Charles Casper Stockham'],
#  ['1638387', 'Jefferson', 'Charles Casper Stockham'],
#  ['1364104', 'Jefferson', 'Charles Casper Stockham'],
#  ['1661128', 'Jefferson', 'Charles Casper Stockham'],
#  ['1425856', 'Jefferson', 'Charles Casper Stockham'],
#  ['1570171', 'Jefferson', 'Charles Casper Stockham'],
#  ['1185919', 'Jefferson', 'Charles Casper Stockham'],
#  ['1940478', 'Jefferson', 'Charles Casper Stockham'],
#  ['1725726', 'Jefferson', 'Charles Casper Stockham'],
#  ['1280245', 'Jefferson', 'Charles Casper Stockham'],
#  ['1807326', 'Jefferson', 'Charles Casper Stockham'],
#  ['1654113', 'Jefferson', 'Charles Casper Stockham'],
#  ['1878492', 'Jefferson', 'Charles Casper Stockham'],
#  ['1930102', 'Jefferson', 'Charles Casper Stockham'],
#  ['1474912', 'Jefferson', 'Charles Casper Stockham'],
#  ['1028506', 'Jefferson', 'Charles Casper Stockham'],
#  ['1142938', 'Jefferson', 'Charles Casper Stockham'],
#  ['1154142', 'Jefferson', 'Charles Casper Stockham'],
#  ['1609904', 'Jefferson', 'Charles Casper Stockham'],
#  ['1721650', 'Jefferson', 'Charles Casper Stockham'],
#  ['1352439', 'Jefferson', 'Charles Casper Stockham'],
#  ['1634412', 'Jefferson', 'Charles Casper Stockham'],
#  ['1847892', 'Jefferson', 'Charles Casper Stockham'],
#  ['1767914', 'Jefferson', 'Charles Casper Stockham'],
#  ['1800169', 'Jefferson', 'Charles Casper Stockham'],
#  ['1021989', 'Jefferson', 'Charles Casper Stockham'],
#  ['1685318', 'Jefferson', 'Charles Casper Stockham'],
#  ['1591330', 'Jefferson', 'Charles Casper Stockham'],
#  ['1730692', 'Jefferson', 'Charles Casper Stockham'],
#  ['1379101', 'Jefferson', 'Charles Casper Stockham'],
#  ['1645941', 'Jefferson', 'Charles Casper Stockham'],
#  ['1726200', 'Jefferson', 'Charles Casper Stockham'],
#  ['1439065', 'Jefferson', 'Charles Casper Stockham'],
#  ['1218174', 'Jefferson', 'Charles Casper Stockham'],
#  ['1015734', 'Jefferson', 'Charles Casper Stockham'],
#  ['1697245', 'Jefferson', 'Charles Casper Stockham'],
#  ['1824909', 'Jefferson', 'Charles Casper Stockham'],
#  ['1229846', 'Jefferson', 'Charles Casper Stockham'],
#  ['1549214', 'Jefferson', 'Charles Casper Stockham'],
#  ['1717553', 'Jefferson', 'Charles Casper Stockham'],
#  ['1865377', 'Jefferson', 'Charles Casper Stockham'],
#  ['1762010', 'Jefferson', 'Charles Casper Stockham'],
#  ['1356344', 'Jefferson', 'Charles Casper Stockham'],
#  ['1444320', 'Jefferson', 'Charles Casper Stockham'],
#  ['1727735', 'Jefferson', 'Charles Casper Stockham'],
#  ['1107874', 'Jefferson', 'Charles Casper Stockham'],
#  ['1317997', 'Jefferson', 'Charles Casper Stockham'],
#  ['1760624', 'Jefferson', 'Charles Casper Stockham'],
#  ['1710133', 'Jefferson', 'Charles Casper Stockham'],
#  ['1772021', 'Jefferson', 'Charles Casper Stockham'],
#  ['1733565', 'Jefferson', 'Charles Casper Stockham'],
#  ['1012319', 'Jefferson', 'Charles Casper Stockham'],
#  ['1692850', 'Jefferson', 'Charles Casper Stockham'],
#  ['1765428', 'Jefferson', 'Charles Casper Stockham'],
#  ['1374483', 'Jefferson', 'Charles Casper Stockham'],
#  ['1527499', 'Jefferson', 'Charles Casper Stockham'],
#  ['1306653', 'Jefferson', 'Charles Casper Stockham'],
#  ['1164233', 'Jefferson', 'Charles Casper Stockham'],
#  ['1603379', 'Jefferson', 'Charles Casper Stockham'],
#  ['1996086', 'Jefferson', 'Charles Casper Stockham'],
#  ['1082319', 'Jefferson', 'Charles Casper Stockham'],
#  ['1659143', 'Jefferson', 'Charles Casper Stockham'],
#  ['1527231', 'Jefferson', 'Charles Casper Stockham'],
#  ['1791047', 'Jefferson', 'Charles Casper Stockham'],
#  ['1121014', 'Jefferson', 'Charles Casper Stockham'],
#  ['1930042', 'Jefferson', 'Charles Casper Stockham'],
#  ['1021284', 'Jefferson', 'Charles Casper Stockham'],
#  ['1481301', 'Jefferson', 'Charles Casper Stockham'],
#  ['1819744', 'Jefferson', 'Charles Casper Stockham'],
#  ['1884441', 'Jefferson', 'Charles Casper Stockham'],
#  ['1401287', 'Jefferson', 'Charles Casper Stockham'],
#  ['1197878', 'Jefferson', 'Charles Casper Stockham'],
#  ['1968677', 'Jefferson', 'Charles Casper Stockham'],
#  ['1082610', 'Jefferson', 'Charles Casper Stockham'],
#  ['1481599', 'Jefferson', 'Charles Casper Stockham'],
#  ['1482806', 'Jefferson', 'Charles Casper Stockham'],
#  ['1495195', 'Jefferson', 'Charles Casper Stockham'],
#  ['1141809', 'Jefferson', 'Charles Casper Stockham'],
#  ['1419757', 'Jefferson', 'Charles Casper Stockham'],
#  ['1790355', 'Jefferson', 'Charles Casper Stockham'],
#  ['1402911', 'Jefferson', 'Charles Casper Stockham'],
#  ['1774119', 'Jefferson', 'Charles Casper Stockham'],
#  ['1501889', 'Jefferson', 'Charles Casper Stockham'],
#  ['1337578', 'Jefferson', 'Charles Casper Stockham'],
#  ['1449541', 'Jefferson', 'Charles Casper Stockham'],
#  ['1716163', 'Jefferson', 'Charles Casper Stockham'],
#  ['1311872', 'Jefferson', 'Charles Casper Stockham'],
#  ['1515115', 'Jefferson', 'Charles Casper Stockham'],
#  ['1458840', 'Jefferson', 'Charles Casper Stockham'],
#  ['1950406', 'Jefferson', 'Charles Casper Stockham'],
#  ['1521363', 'Jefferson', 'Charles Casper Stockham'],
#  ['1016261', 'Jefferson', 'Charles Casper Stockham'],
#  ['1248093', 'Jefferson', 'Charles Casper Stockham'],
#  ['1132091', 'Jefferson', 'Charles Casper Stockham'],
#  ['1905090', 'Jefferson', 'Charles Casper Stockham'],
#  ['1897709', 'Jefferson', 'Charles Casper Stockham'],
#  ['1804133', 'Jefferson', 'Charles Casper Stockham'],
#  ['1472822', 'Jefferson', 'Charles Casper Stockham'],
#  ['1224841', 'Jefferson', 'Charles Casper Stockham'],
#  ['1269351', 'Jefferson', 'Charles Casper Stockham'],
#  ['1697636', 'Jefferson', 'Charles Casper Stockham'],
#  ['1666871', 'Jefferson', 'Charles Casper Stockham'],
#  ['1369718', 'Jefferson', 'Charles Casper Stockham'],
#  ['1172395', 'Jefferson', 'Charles Casper Stockham'],
#  ['1873099', 'Jefferson', 'Charles Casper Stockham'],
#  ['1988530', 'Jefferson', 'Charles Casper Stockham'],
#  ['1416461', 'Jefferson', 'Charles Casper Stockham'],
#  ['1075357', 'Jefferson', 'Charles Casper Stockham'],
#  ['1603674', 'Jefferson', 'Charles Casper Stockham'],
#  ['1560960', 'Jefferson', 'Charles Casper Stockham'],
#  ['1406899', 'Jefferson', 'Charles Casper Stockham'],
#  ['1889389', 'Jefferson', 'Charles Casper Stockham'],
#  ['1320634', 'Jefferson', 'Charles Casper Stockham'],
#  ['1509363', 'Jefferson', 'Charles Casper Stockham'],
#  ['1229425', 'Jefferson', 'Charles Casper Stockham'],
#  ['1751248', 'Jefferson', 'Charles Casper Stockham'],
#  ['1649478', 'Jefferson', 'Charles Casper Stockham'],
#  ['1217097', 'Jefferson', 'Charles Casper Stockham'],
#  ['1331130', 'Jefferson', 'Charles Casper Stockham'],
#  ['1588992', 'Jefferson', 'Charles Casper Stockham'],
#  ['1694060', 'Jefferson', 'Charles Casper Stockham'],
#  ['1024983', 'Jefferson', 'Charles Casper Stockham'],
#  ['1581463', 'Jefferson', 'Charles Casper Stockham'],
#  ['1857475', 'Jefferson', 'Charles Casper Stockham'],
#  ['1106932', 'Jefferson', 'Charles Casper Stockham'],
#  ['1197209', 'Jefferson', 'Charles Casper Stockham'],
#  ['1844317', 'Jefferson', 'Charles Casper Stockham'],
#  ['1158972', 'Jefferson', 'Charles Casper Stockham'],
#  ['1479234', 'Jefferson', 'Charles Casper Stockham'],
#  ['1245954', 'Jefferson', 'Charles Casper Stockham'],
#  ['1807490', 'Jefferson', 'Charles Casper Stockham'],
#  ['1246906', 'Jefferson', 'Charles Casper Stockham'],
#  ['1663735', 'Jefferson', 'Charles Casper Stockham'],
#  ['1571264', 'Jefferson', 'Charles Casper Stockham'],
#  ['1219676', 'Jefferson', 'Charles Casper Stockham'],
#  ['1141481', 'Jefferson', 'Charles Casper Stockham'],
#  ['1757937', 'Jefferson', 'Charles Casper Stockham'],
#  ['1382133', 'Jefferson', 'Charles Casper Stockham'],
#  ['1972551', 'Jefferson', 'Charles Casper Stockham'],
#  ['1666838', 'Jefferson', 'Charles Casper Stockham'],
#  ['1071576', 'Jefferson', 'Charles Casper Stockham'],
#  ['1341723', 'Jefferson', 'Charles Casper Stockham'],
#  ['1327109', 'Jefferson', 'Charles Casper Stockham'],
#  ['1716278', 'Jefferson', 'Charles Casper Stockham'],
#  ['1748101', 'Jefferson', 'Charles Casper Stockham'],
#  ['1548106', 'Jefferson', 'Charles Casper Stockham'],
#  ['1976343', 'Jefferson', 'Charles Casper Stockham'],
#  ['1729544', 'Jefferson', 'Charles Casper Stockham'],
#  ['1884772', 'Jefferson', 'Charles Casper Stockham'],
#  ['1396463', 'Jefferson', 'Charles Casper Stockham'],
#  ['1944703', 'Jefferson', 'Charles Casper Stockham'],
#  ['1960223', 'Jefferson', 'Charles Casper Stockham'],
#  ['1282204', 'Jefferson', 'Charles Casper Stockham'],
#  ['1561729', 'Jefferson', 'Charles Casper Stockham'],
#  ['1879927', 'Jefferson', 'Charles Casper Stockham'],
#  ['1006388', 'Jefferson', 'Charles Casper Stockham'],
#  ['1492059', 'Jefferson', 'Charles Casper Stockham'],
#  ['1999022', 'Jefferson', 'Charles Casper Stockham'],
#  ['1619923', 'Jefferson', 'Charles Casper Stockham'],
#  ['1889926', 'Jefferson', 'Charles Casper Stockham'],
#  ['1334039', 'Jefferson', 'Charles Casper Stockham'],
#  ['1015610', 'Jefferson', 'Charles Casper Stockham'],
#  ['1493461', 'Jefferson', 'Charles Casper Stockham'],
#  ['1600553', 'Jefferson', 'Charles Casper Stockham'],
#  ['1019192', 'Jefferson', 'Charles Casper Stockham'],
#  ['1517327', 'Jefferson', 'Charles Casper Stockham'],
#  ['1456026', 'Jefferson', 'Charles Casper Stockham'],
#  ['1636398', 'Jefferson', 'Charles Casper Stockham'],
#  ['1103310', 'Jefferson', 'Charles Casper Stockham'],
#  ['1136568', 'Jefferson', 'Charles Casper Stockham'],
#  ['1244882', 'Jefferson', 'Charles Casper Stockham'],
#  ['1391642', 'Jefferson', 'Charles Casper Stockham'],
#  ['1413846', 'Jefferson', 'Charles Casper Stockham'],
#  ['1867288', 'Jefferson', 'Charles Casper Stockham'],
#  ['1796733', 'Jefferson', 'Charles Casper Stockham'],
#  ['1638732', 'Jefferson', 'Charles Casper Stockham'],
#  ['1026594', 'Jefferson', 'Charles Casper Stockham'],
#  ['1456233', 'Jefferson', 'Charles Casper Stockham'],
#  ['1684553', 'Jefferson', 'Charles Casper Stockham'],
#  ['1391340', 'Jefferson', 'Charles Casper Stockham'],
#  ['1449669', 'Jefferson', 'Charles Casper Stockham'],
#  ['1073702', 'Jefferson', 'Charles Casper Stockham'],
#  ['1651790', 'Jefferson', 'Charles Casper Stockham'],
#  ['1701282', 'Jefferson', 'Charles Casper Stockham'],
#  ['1906455', 'Jefferson', 'Charles Casper Stockham'],
#  ['1067368', 'Jefferson', 'Charles Casper Stockham'],
#  ['1715197', 'Jefferson', 'Charles Casper Stockham'],
#  ['1001799', 'Jefferson', 'Charles Casper Stockham'],
#  ['1205688', 'Jefferson', 'Charles Casper Stockham'],
#  ['1012672', 'Jefferson', 'Charles Casper Stockham'],
#  ['1472173', 'Jefferson', 'Charles Casper Stockham'],
#  ['1565536', 'Jefferson', 'Charles Casper Stockham'],
#  ['1324405', 'Jefferson', 'Charles Casper Stockham'],
#  ['1868405', 'Jefferson', 'Charles Casper Stockham'],
#  ['1901862', 'Jefferson', 'Charles Casper Stockham'],
#  ['1371047', 'Jefferson', 'Charles Casper Stockham'],
#  ['1716026', 'Jefferson', 'Charles Casper Stockham'],
#  ['1367802', 'Jefferson', 'Charles Casper Stockham'],
#  ['1562699', 'Jefferson', 'Charles Casper Stockham'],
#  ['1741194', 'Jefferson', 'Charles Casper Stockham'],
#  ['1758000', 'Jefferson', 'Charles Casper Stockham'],
#  ['1383457', 'Jefferson', 'Charles Casper Stockham'],
#  ['1092192', 'Jefferson', 'Charles Casper Stockham'],
#  ['1138623', 'Jefferson', 'Charles Casper Stockham'],
#  ['1865359', 'Jefferson', 'Charles Casper Stockham'],
#  ['1572649', 'Jefferson', 'Charles Casper Stockham'],
#  ['1588837', 'Jefferson', 'Charles Casper Stockham'],
#  ['1054678', 'Jefferson', 'Charles Casper Stockham'],
#  ['1349235', 'Jefferson', 'Charles Casper Stockham'],
#  ['1496437', 'Jefferson', 'Charles Casper Stockham'],
#  ['1219096', 'Jefferson', 'Charles Casper Stockham'],
#  ['1281410', 'Jefferson', 'Charles Casper Stockham'],
#  ['1233076', 'Jefferson', 'Charles Casper Stockham'],
#  ['1435423', 'Jefferson', 'Charles Casper Stockham'],
#  ['1052746', 'Jefferson', 'Charles Casper Stockham'],
#  ['1718517', 'Jefferson', 'Charles Casper Stockham'],
#  ['1881149', 'Jefferson', 'Charles Casper Stockham'],
#  ['1070673', 'Jefferson', 'Charles Casper Stockham'],
#  ['1686740', 'Jefferson', 'Charles Casper Stockham'],
#  ['1925123', 'Jefferson', 'Charles Casper Stockham'],
#  ['1451649', 'Jefferson', 'Charles Casper Stockham'],
#  ['1234826', 'Jefferson', 'Charles Casper Stockham'],
#  ['1696856', 'Jefferson', 'Charles Casper Stockham'],
#  ['1074415', 'Jefferson', 'Charles Casper Stockham'],
#  ['1500738', 'Jefferson', 'Charles Casper Stockham'],
#  ['1798073', 'Jefferson', 'Charles Casper Stockham'],
#  ['1385642', 'Jefferson', 'Charles Casper Stockham'],
#  ['1959310', 'Jefferson', 'Charles Casper Stockham'],
#  ['1191136', 'Jefferson', 'Charles Casper Stockham'],
#  ['1350417', 'Jefferson', 'Charles Casper Stockham'],
#  ['1914580', 'Jefferson', 'Charles Casper Stockham'],
#  ['1933446', 'Jefferson', 'Charles Casper Stockham'],
#  ['1011347', 'Jefferson', 'Charles Casper Stockham'],
#  ['1741976', 'Jefferson', 'Charles Casper Stockham'],
#  ['1995100', 'Jefferson', 'Charles Casper Stockham'],
#  ['1680694', 'Jefferson', 'Charles Casper Stockham'],
#  ['1269638', 'Jefferson', 'Charles Casper Stockham'],
#  ['1979247', 'Jefferson', 'Charles Casper Stockham'],
#  ['1067252', 'Jefferson', 'Charles Casper Stockham'],
#  ['1955497', 'Jefferson', 'Charles Casper Stockham'],
#  ['1380047', 'Jefferson', 'Charles Casper Stockham'],
#  ['1317855', 'Jefferson', 'Charles Casper Stockham'],
#  ['1084300', 'Jefferson', 'Charles Casper Stockham'],
#  ['1214104', 'Jefferson', 'Charles Casper Stockham'],
#  ['1191437', 'Jefferson', 'Charles Casper Stockham'],
#  ['1157254', 'Jefferson', 'Charles Casper Stockham'],
#  ['1911302', 'Jefferson', 'Charles Casper Stockham'],
#  ['1447646', 'Jefferson', 'Charles Casper Stockham'],
#  ['1331797', 'Jefferson', 'Charles Casper Stockham'],
#  ['1817447', 'Jefferson', 'Charles Casper Stockham'],
#  ['1530685', 'Jefferson', 'Charles Casper Stockham'],
#  ['1491122', 'Jefferson', 'Charles Casper Stockham'],
#  ['1163618', 'Jefferson', 'Charles Casper Stockham'],
#  ['1842559', 'Jefferson', 'Charles Casper Stockham'],
#  ['1414013', 'Jefferson', 'Charles Casper Stockham'],
#  ['1751217', 'Jefferson', 'Charles Casper Stockham'],
#  ['1440842', 'Jefferson', 'Charles Casper Stockham'],
#  ['1506930', 'Jefferson', 'Charles Casper Stockham'],
#  ['1500155', 'Jefferson', 'Charles Casper Stockham'],
#  ['1260546', 'Jefferson', 'Charles Casper Stockham'],
#  ['1862435', 'Jefferson', 'Charles Casper Stockham'],
#  ['1679101', 'Jefferson', 'Charles Casper Stockham'],
#  ['1739121', 'Jefferson', 'Charles Casper Stockham'],
#  ['1668247', 'Jefferson', 'Charles Casper Stockham'],
#  ['1373285', 'Jefferson', 'Charles Casper Stockham'],
#  ['1293599', 'Jefferson', 'Charles Casper Stockham'],
#  ['1014164', 'Jefferson', 'Charles Casper Stockham'],
#  ['1309913', 'Jefferson', 'Charles Casper Stockham'],
#  ['1163780', 'Jefferson', 'Charles Casper Stockham'],
#  ['1569777', 'Jefferson', 'Charles Casper Stockham'],
#  ['1580452', 'Jefferson', 'Charles Casper Stockham'],
#  ['1692566', 'Jefferson', 'Charles Casper Stockham'],
#  ['1151309', 'Jefferson', 'Charles Casper Stockham'],
#  ['1179057', 'Jefferson', 'Charles Casper Stockham'],
#  ['1438132', 'Jefferson', 'Charles Casper Stockham'],
#  ['1203815', 'Jefferson', 'Charles Casper Stockham'],
#  ['1693823', 'Jefferson', 'Charles Casper Stockham'],
#  ['1504687', 'Jefferson', 'Charles Casper Stockham'],
#  ['1561790', 'Jefferson', 'Charles Casper Stockham'],
#  ['1583051', 'Jefferson', 'Charles Casper Stockham'],
#  ['1189026', 'Jefferson', 'Charles Casper Stockham'],
#  ['1072094', 'Jefferson', 'Charles Casper Stockham'],
#  ['1244038', 'Jefferson', 'Charles Casper Stockham'],
#  ['1366350', 'Jefferson', 'Charles Casper Stockham'],
#  ['1505647', 'Jefferson', 'Charles Casper Stockham'],
#  ['1199829', 'Jefferson', 'Charles Casper Stockham'],
#  ['1674648', 'Jefferson', 'Charles Casper Stockham'],
#  ['1364883', 'Jefferson', 'Charles Casper Stockham'],
#  ['1447415', 'Jefferson', 'Charles Casper Stockham'],
#  ['1504861', 'Jefferson', 'Charles Casper Stockham'],
#  ['1799024', 'Jefferson', 'Charles Casper Stockham'],
#  ['1319713', 'Jefferson', 'Charles Casper Stockham'],
#  ['1163718', 'Jefferson', 'Charles Casper Stockham'],
#  ['1017874', 'Jefferson', 'Charles Casper Stockham'],
#  ['1335614', 'Jefferson', 'Charles Casper Stockham'],
#  ['1503975', 'Jefferson', 'Charles Casper Stockham'],
#  ['1979493', 'Jefferson', 'Charles Casper Stockham'],
#  ['1385834', 'Jefferson', 'Charles Casper Stockham'],
#  ['1638661', 'Jefferson', 'Charles Casper Stockham'],
#  ['1611425', 'Jefferson', 'Charles Casper Stockham'],
#  ['1907275', 'Jefferson', 'Charles Casper Stockham'],
#  ['1293455', 'Jefferson', 'Charles Casper Stockham'],
#  ['1734219', 'Jefferson', 'Charles Casper Stockham'],
#  ['1121166', 'Jefferson', 'Charles Casper Stockham'],
#  ['1694099', 'Jefferson', 'Charles Casper Stockham'],
#  ['1844767', 'Jefferson', 'Charles Casper Stockham'],
#  ['1576948', 'Jefferson', 'Charles Casper Stockham'],
#  ['1281520', 'Jefferson', 'Charles Casper Stockham'],
#  ['1647137', 'Jefferson', 'Charles Casper Stockham'],
#  ['1644175', 'Jefferson', 'Charles Casper Stockham'],
#  ['1882652', 'Jefferson', 'Charles Casper Stockham'],
#  ['1928356', 'Jefferson', 'Charles Casper Stockham'],
#  ['1167551', 'Jefferson', 'Charles Casper Stockham'],
#  ['1310745', 'Jefferson', 'Charles Casper Stockham'],
#  ['1002936', 'Jefferson', 'Charles Casper Stockham'],
#  ['1620507', 'Jefferson', 'Charles Casper Stockham'],
#  ['1101386', 'Jefferson', 'Charles Casper Stockham'],
#  ['1811033', 'Jefferson', 'Charles Casper Stockham'],
#  ['1308527', 'Jefferson', 'Charles Casper Stockham'],
#  ['1590885', 'Jefferson', 'Charles Casper Stockham'],
#  ['1584419', 'Jefferson', 'Charles Casper Stockham'],
#  ['1682106', 'Jefferson', 'Charles Casper Stockham'],
#  ['1971035', 'Jefferson', 'Charles Casper Stockham'],
#  ['1564572', 'Jefferson', 'Charles Casper Stockham'],
#  ['1127394', 'Jefferson', 'Charles Casper Stockham'],
#  ['1775532', 'Jefferson', 'Charles Casper Stockham'],
#  ['1966907', 'Jefferson', 'Charles Casper Stockham'],
#  ['1441429', 'Jefferson', 'Charles Casper Stockham'],
#  ['1209474', 'Jefferson', 'Charles Casper Stockham'],
#  ['1961943', 'Jefferson', 'Charles Casper Stockham'],
#  ['1765000', 'Jefferson', 'Charles Casper Stockham'],
#  ['1177648', 'Jefferson', 'Charles Casper Stockham'],
#  ['1236632', 'Jefferson', 'Charles Casper Stockham'],
#  ['1456868', 'Jefferson', 'Charles Casper Stockham'],
#  ['1268414', 'Jefferson', 'Charles Casper Stockham'],
#  ['1070650', 'Jefferson', 'Charles Casper Stockham'],
#  ['1226175', 'Jefferson', 'Charles Casper Stockham'],
#  ['1821742', 'Jefferson', 'Charles Casper Stockham'],
#  ['1804957', 'Jefferson', 'Charles Casper Stockham'],
#  ['1461840', 'Jefferson', 'Charles Casper Stockham'],
#  ['1995190', 'Jefferson', 'Charles Casper Stockham'],
#  ['1820410', 'Jefferson', 'Charles Casper Stockham'],
#  ['1908487', 'Jefferson', 'Charles Casper Stockham'],
#  ['1919643', 'Jefferson', 'Charles Casper Stockham'],
#  ['1518577', 'Jefferson', 'Charles Casper Stockham'],
#  ['1168451', 'Jefferson', 'Charles Casper Stockham'],
#  ['1146555', 'Jefferson', 'Charles Casper Stockham'],
#  ['1855214', 'Jefferson', 'Charles Casper Stockham'],
#  ['1607265', 'Jefferson', 'Charles Casper Stockham'],
#  ['1576605', 'Jefferson', 'Charles Casper Stockham'],
#  ['1573830', 'Jefferson', 'Charles Casper Stockham'],
#  ['1525516', 'Jefferson', 'Charles Casper Stockham'],
#  ['1515306', 'Jefferson', 'Charles Casper Stockham'],
#  ['1402667', 'Jefferson', 'Charles Casper Stockham'],
#  ['1503281', 'Jefferson', 'Charles Casper Stockham'],
#  ['1077829', 'Jefferson', 'Charles Casper Stockham'],
#  ['1229369', 'Jefferson', 'Charles Casper Stockham'],
#  ['1924118', 'Jefferson', 'Charles Casper Stockham'],
#  ['1277707', 'Jefferson', 'Charles Casper Stockham'],
#  ['1290272', 'Jefferson', 'Charles Casper Stockham'],
#  ['1456595', 'Jefferson', 'Charles Casper Stockham'],
#  ['1475797', 'Jefferson', 'Charles Casper Stockham'],
#  ['1588401', 'Jefferson', 'Charles Casper Stockham'],
#  ['1606175', 'Jefferson', 'Charles Casper Stockham'],
#  ['1990148', 'Jefferson', 'Charles Casper Stockham'],
#  ['1279923', 'Jefferson', 'Charles Casper Stockham'],
#  ['1614056', 'Jefferson', 'Charles Casper Stockham'],
#  ['1617245', 'Jefferson', 'Charles Casper Stockham'],
#  ['1883000', 'Jefferson', 'Charles Casper Stockham'],
#  ['1709386', 'Jefferson', 'Charles Casper Stockham'],
#  ['1093352', 'Jefferson', 'Charles Casper Stockham'],
#  ['1590785', 'Jefferson', 'Charles Casper Stockham'],
#  ['1447418', 'Jefferson', 'Charles Casper Stockham'],
#  ['1664646', 'Jefferson', 'Charles Casper Stockham'],
#  ['1204279', 'Jefferson', 'Charles Casper Stockham'],
#  ['1988155', 'Jefferson', 'Charles Casper Stockham'],
#  ['1315265', 'Jefferson', 'Charles Casper Stockham'],
#  ['1695591', 'Jefferson', 'Charles Casper Stockham'],
#  ['1384584', 'Jefferson', 'Charles Casper Stockham'],
#  ['1608162', 'Jefferson', 'Charles Casper Stockham'],
#  ['1774769', 'Jefferson', 'Charles Casper Stockham'],
#  ['1507337', 'Jefferson', 'Charles Casper Stockham'],
#  ['1302910', 'Jefferson', 'Charles Casper Stockham'],
#  ['1357824', 'Jefferson', 'Charles Casper Stockham'],
#  ['1460253', 'Jefferson', 'Charles Casper Stockham'],
#  ['1125299', 'Jefferson', 'Charles Casper Stockham'],
#  ['1522294', 'Jefferson', 'Charles Casper Stockham'],
#  ['1587847', 'Jefferson', 'Charles Casper Stockham'],
#  ['1707792', 'Jefferson', 'Charles Casper Stockham'],
#  ['1991897', 'Jefferson', 'Charles Casper Stockham'],
#  ['1667300', 'Jefferson', 'Charles Casper Stockham'],
#  ['1066748', 'Jefferson', 'Charles Casper Stockham'],
#  ['1287138', 'Jefferson', 'Charles Casper Stockham'],
#  ['1385247', 'Jefferson', 'Charles Casper Stockham'],
#  ['1331612', 'Jefferson', 'Charles Casper Stockham'],
#  ['1501080', 'Jefferson', 'Charles Casper Stockham'],
#  ['1789366', 'Jefferson', 'Charles Casper Stockham'],
#  ['1869517', 'Jefferson', 'Charles Casper Stockham'],
#  ['1253818', 'Jefferson', 'Charles Casper Stockham'],
#  ['1185967', 'Jefferson', 'Charles Casper Stockham'],
#  ['1459539', 'Jefferson', 'Charles Casper Stockham'],
#  ['1697980', 'Jefferson', 'Charles Casper Stockham'],
#  ['1249919', 'Jefferson', 'Charles Casper Stockham'],
#  ['1094964', 'Jefferson', 'Charles Casper Stockham'],
#  ['1268196', 'Jefferson', 'Charles Casper Stockham'],
#  ['1361914', 'Jefferson', 'Charles Casper Stockham'],
#  ['1813070', 'Jefferson', 'Charles Casper Stockham'],
#  ['1967312', 'Jefferson', 'Charles Casper Stockham'],
#  ['1385790', 'Jefferson', 'Charles Casper Stockham'],
#  ['1305148', 'Jefferson', 'Charles Casper Stockham'],
#  ['1600497', 'Jefferson', 'Charles Casper Stockham'],
#  ['1974378', 'Jefferson', 'Charles Casper Stockham'],
#  ['1106282', 'Jefferson', 'Charles Casper Stockham'],
#  ['1821339', 'Jefferson', 'Charles Casper Stockham'],
#  ['1088842', 'Jefferson', 'Charles Casper Stockham'],
#  ['1159131', 'Jefferson', 'Charles Casper Stockham'],
#  ['1580003', 'Jefferson', 'Charles Casper Stockham'],
#  ['1826733', 'Jefferson', 'Charles Casper Stockham'],
#  ['1226451', 'Jefferson', 'Charles Casper Stockham'],
#  ['1754153', 'Jefferson', 'Charles Casper Stockham'],
#  ['1936984', 'Jefferson', 'Charles Casper Stockham'],
#  ['1942098', 'Jefferson', 'Charles Casper Stockham'],
#  ['1535287', 'Jefferson', 'Charles Casper Stockham'],
#  ['1429393', 'Jefferson', 'Charles Casper Stockham'],
#  ['1263530', 'Jefferson', 'Charles Casper Stockham'],
#  ['1851197', 'Jefferson', 'Charles Casper Stockham'],
#  ['1808858', 'Jefferson', 'Charles Casper Stockham'],
#  ['1807541', 'Jefferson', 'Charles Casper Stockham'],
#  ['1354607', 'Jefferson', 'Charles Casper Stockham'],
#  ['1779544', 'Jefferson', 'Charles Casper Stockham'],
#  ['1728010', 'Jefferson', 'Charles Casper Stockham'],
#  ['1418989', 'Jefferson', 'Charles Casper Stockham'],
#  ['1133413', 'Jefferson', 'Charles Casper Stockham'],
#  ['1885562', 'Jefferson', 'Charles Casper Stockham'],
#  ['1619747', 'Jefferson', 'Charles Casper Stockham'],
#  ['1831108', 'Jefferson', 'Charles Casper Stockham'],
#  ['1480368', 'Jefferson', 'Charles Casper Stockham'],
#  ['1724322', 'Jefferson', 'Charles Casper Stockham'],
#  ['1469063', 'Jefferson', 'Charles Casper Stockham'],
#  ['1336049', 'Jefferson', 'Charles Casper Stockham'],
#  ['1456359', 'Jefferson', 'Charles Casper Stockham'],
#  ['1978781', 'Jefferson', 'Charles Casper Stockham'],
#  ['1910056', 'Jefferson', 'Charles Casper Stockham'],
#  ['1504495', 'Jefferson', 'Charles Casper Stockham'],
#  ['1507992', 'Jefferson', 'Charles Casper Stockham'],
#  ['1351343', 'Jefferson', 'Charles Casper Stockham'],
#  ['1190873', 'Jefferson', 'Charles Casper Stockham'],
#  ['1729112', 'Jefferson', 'Charles Casper Stockham'],
#  ['1142284', 'Jefferson', 'Charles Casper Stockham'],
#  ['1852173', 'Jefferson', 'Charles Casper Stockham'],
#  ['1751319', 'Jefferson', 'Charles Casper Stockham'],
#  ['1753429', 'Jefferson', 'Charles Casper Stockham'],
#  ['1292398', 'Jefferson', 'Charles Casper Stockham'],
#  ['1293602', 'Jefferson', 'Charles Casper Stockham'],
#  ['1334086', 'Jefferson', 'Charles Casper Stockham'],
#  ['1710543', 'Jefferson', 'Charles Casper Stockham'],
#  ['1479685', 'Jefferson', 'Charles Casper Stockham'],
#  ['1637548', 'Jefferson', 'Charles Casper Stockham'],
#  ['1656689', 'Jefferson', 'Charles Casper Stockham'],
#  ['1254647', 'Jefferson', 'Charles Casper Stockham'],
#  ['1779411', 'Jefferson', 'Charles Casper Stockham'],
#  ['1578324', 'Jefferson', 'Charles Casper Stockham'],
#  ['1072566', 'Jefferson', 'Charles Casper Stockham'],
#  ['1200532', 'Jefferson', 'Charles Casper Stockham'],
#  ['1843649', 'Jefferson', 'Charles Casper Stockham'],
#  ['1701304', 'Jefferson', 'Charles Casper Stockham'],
#  ['1349542', 'Jefferson', 'Charles Casper Stockham'],
#  ['1347793', 'Jefferson', 'Charles Casper Stockham'],
#  ['1405932', 'Jefferson', 'Charles Casper Stockham'],
#  ['1581800', 'Jefferson', 'Charles Casper Stockham'],
#  ['1034336', 'Jefferson', 'Charles Casper Stockham'],
#  ['1964390', 'Jefferson', 'Charles Casper Stockham'],
#  ['1267766', 'Jefferson', 'Charles Casper Stockham'],
#  ['1834942', 'Jefferson', 'Charles Casper Stockham'],
#  ['1535913', 'Jefferson', 'Charles Casper Stockham'],
#  ['1719400', 'Jefferson', 'Charles Casper Stockham'],
#  ['1103722', 'Jefferson', 'Charles Casper Stockham'],
#  ['1609870', 'Jefferson', 'Charles Casper Stockham'],
#  ['1062251', 'Jefferson', 'Charles Casper Stockham'],
#  ['1507830', 'Jefferson', 'Charles Casper Stockham'],
#  ['1628124', 'Jefferson', 'Charles Casper Stockham'],
#  ['1775891', 'Jefferson', 'Charles Casper Stockham'],
#  ['1819734', 'Jefferson', 'Charles Casper Stockham'],
#  ['1490599', 'Jefferson', 'Charles Casper Stockham'],
#  ['1854515', 'Jefferson', 'Charles Casper Stockham'],
#  ['1175440', 'Jefferson', 'Charles Casper Stockham'],
#  ['1127208', 'Jefferson', 'Charles Casper Stockham'],
#  ['1281400', 'Jefferson', 'Charles Casper Stockham'],
#  ['1954320', 'Jefferson', 'Charles Casper Stockham'],
#  ['1127216', 'Jefferson', 'Charles Casper Stockham'],
#  ['1631961', 'Jefferson', 'Charles Casper Stockham'],
#  ['1878394', 'Jefferson', 'Charles Casper Stockham'],
#  ['1428069', 'Jefferson', 'Charles Casper Stockham'],
#  ['1188590', 'Jefferson', 'Charles Casper Stockham'],
#  ['1519838', 'Jefferson', 'Charles Casper Stockham'],
#  ['1147671', 'Jefferson', 'Charles Casper Stockham'],
#  ['1998004', 'Jefferson', 'Charles Casper Stockham'],
#  ['1347625', 'Jefferson', 'Charles Casper Stockham'],
#  ['1747312', 'Jefferson', 'Charles Casper Stockham'],
#  ['1580197', 'Jefferson', 'Charles Casper Stockham'],
#  ['1594997', 'Jefferson', 'Charles Casper Stockham'],
#  ['1294596', 'Jefferson', 'Charles Casper Stockham'],
#  ['1141913', 'Jefferson', 'Charles Casper Stockham'],
#  ['1271849', 'Jefferson', 'Charles Casper Stockham'],
#  ['1227895', 'Jefferson', 'Charles Casper Stockham'],
#  ['1445142', 'Jefferson', 'Charles Casper Stockham'],
#  ['1863389', 'Jefferson', 'Charles Casper Stockham'],
#  ['1429215', 'Jefferson', 'Charles Casper Stockham'],
#  ['1602258', 'Jefferson', 'Charles Casper Stockham'],
#  ['1059665', 'Jefferson', 'Charles Casper Stockham'],
#  ['1983814', 'Jefferson', 'Charles Casper Stockham'],
#  ['1483887', 'Jefferson', 'Charles Casper Stockham'],
#  ['1068607', 'Jefferson', 'Charles Casper Stockham'],
#  ['1562991', 'Jefferson', 'Charles Casper Stockham'],
#  ['1832724', 'Jefferson', 'Charles Casper Stockham'],
#  ['1945578', 'Jefferson', 'Charles Casper Stockham'],
#  ['1778415', 'Jefferson', 'Charles Casper Stockham'],
#  ['1246391', 'Jefferson', 'Charles Casper Stockham'],
#  ['1554642', 'Jefferson', 'Charles Casper Stockham'],
#  ['1112361', 'Jefferson', 'Charles Casper Stockham'],
#  ['1203949', 'Jefferson', 'Charles Casper Stockham'],
#  ['1117763', 'Jefferson', 'Charles Casper Stockham'],
#  ['1939336', 'Jefferson', 'Charles Casper Stockham'],
#  ['1110845', 'Jefferson', 'Charles Casper Stockham'],
#  ['1973146', 'Jefferson', 'Charles Casper Stockham'],
#  ['1770135', 'Jefferson', 'Charles Casper Stockham'],
#  ['1982856', 'Jefferson', 'Charles Casper Stockham'],
#  ['1843223', 'Jefferson', 'Charles Casper Stockham'],
#  ['1476678', 'Jefferson', 'Charles Casper Stockham'],
#  ['1500523', 'Jefferson', 'Charles Casper Stockham'],
#  ['1574926', 'Jefferson', 'Charles Casper Stockham'],
#  ['1766615', 'Jefferson', 'Charles Casper Stockham'],
#  ['1255633', 'Jefferson', 'Charles Casper Stockham'],
#  ['1664792', 'Jefferson', 'Charles Casper Stockham'],
#  ['1528769', 'Jefferson', 'Charles Casper Stockham'],
#  ['1046990', 'Jefferson', 'Charles Casper Stockham'],
#  ['1421758', 'Jefferson', 'Charles Casper Stockham'],
#  ['1639716', 'Jefferson', 'Charles Casper Stockham'],
#  ['1385112', 'Jefferson', 'Charles Casper Stockham'],
#  ['1389501', 'Jefferson', 'Charles Casper Stockham'],
#  ['1348767', 'Jefferson', 'Charles Casper Stockham'],
#  ['1443422', 'Jefferson', 'Charles Casper Stockham'],
#  ['1271118', 'Jefferson', 'Charles Casper Stockham'],
#  ['1116425', 'Jefferson', 'Charles Casper Stockham'],
#  ['1779362', 'Jefferson', 'Charles Casper Stockham'],
#  ['1648352', 'Jefferson', 'Charles Casper Stockham'],
#  ['1280462', 'Jefferson', 'Charles Casper Stockham'],
#  ['1566505', 'Jefferson', 'Charles Casper Stockham'],
#  ['1293412', 'Jefferson', 'Charles Casper Stockham'],
#  ['1632520', 'Jefferson', 'Charles Casper Stockham'],
#  ['1204997', 'Jefferson', 'Charles Casper Stockham'],
#  ['1339513', 'Jefferson', 'Charles Casper Stockham'],
#  ['1476023', 'Jefferson', 'Charles Casper Stockham'],
#  ['1608518', 'Jefferson', 'Charles Casper Stockham'],
#  ['1314313', 'Jefferson', 'Charles Casper Stockham'],
#  ['1832475', 'Jefferson', 'Charles Casper Stockham'],
#  ['1971597', 'Jefferson', 'Charles Casper Stockham'],
#  ['1168076', 'Jefferson', 'Charles Casper Stockham'],
#  ['1436492', 'Jefferson', 'Charles Casper Stockham'],
#  ['1591682', 'Jefferson', 'Charles Casper Stockham'],
#  ['1307542', 'Jefferson', 'Charles Casper Stockham'],
#  ['1871647', 'Jefferson', 'Charles Casper Stockham'],
#  ['1638320', 'Jefferson', 'Charles Casper Stockham'],
#  ['1834977', 'Jefferson', 'Charles Casper Stockham'],
#  ['1759216', 'Jefferson', 'Charles Casper Stockham'],
#  ['1449810', 'Jefferson', 'Charles Casper Stockham'],
#  ['1964413', 'Jefferson', 'Charles Casper Stockham'],
#  ['1159333', 'Jefferson', 'Charles Casper Stockham'],
#  ['1864785', 'Jefferson', 'Charles Casper Stockham'],
#  ['1336238', 'Jefferson', 'Charles Casper Stockham'],
#  ['1866462', 'Jefferson', 'Charles Casper Stockham'],
#  ['1513171', 'Jefferson', 'Charles Casper Stockham'],
#  ['1028730', 'Jefferson', 'Charles Casper Stockham'],
#  ['1454926', 'Jefferson', 'Charles Casper Stockham'],
#  ['1630466', 'Jefferson', 'Charles Casper Stockham'],
#  ['1656553', 'Jefferson', 'Charles Casper Stockham'],
#  ['1860560', 'Jefferson', 'Charles Casper Stockham'],
#  ['1794032', 'Jefferson', 'Charles Casper Stockham'],
#  ['1565739', 'Jefferson', 'Charles Casper Stockham'],
#  ['1714283', 'Jefferson', 'Charles Casper Stockham'],
#  ['1554838', 'Jefferson', 'Charles Casper Stockham'],
#  ['1241289', 'Jefferson', 'Charles Casper Stockham'],
#  ...]

# %%
#Number of votes:
len(data)
# Out:
# 369712

# %%
unique_entries = list(set(sublist[2] for sublist in data))
print("List of unique entries from the second element:", unique_entries)
# Out:
# List of unique entries from the second element: ['Charles Casper Stockham', 'Raymon Anthony Doane', 'Diana DeGette', 'Candidate']

# %%
count_dict = {}
for entry in unique_entries:
    count_dict[entry] = sum(1 for sublist in data if sublist[2] == entry)

print("Count of associated values in Votes:")
for entry, count in count_dict.items():
    print(entry, ":", (count/len(data))*100)
# Out:
# Count of associated values in Votes:
# Charles Casper Stockham : 23.048480979789673
# Raymon Anthony Doane : 3.1392002423508027
# Diana DeGette : 73.81204829705284
# Candidate : 0.00027048080668195786

# %%
#The Winner is Diana DeGette.
